# %% [markdown]
# # 1. Setup and Libraries

# %%
import os
import glob
import json
import numpy as np
import cv2
import mediapipe as mp
import pandas as pd
import concurrent.futures
from scipy.spatial.transform import Rotation
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# # 2. Dataset Directories

# %%
dataset_Folder = "G:/My Drive/GP Datasets/fit3d_data/"
file_path = dataset_Folder + 'fit3d_info.json'

# %% [markdown]
# # 3. Load FIT3D Metadata

# %%
info_JSON = pd.read_json(file_path, typ='series')
print("JSON loaded successfully as a series:")
print(info_JSON.head())

val_subj_names = ['s03', 's11']
all_train = [sub for sub in info_JSON['train_subj_names'] if sub not in val_subj_names]
all_camera_names = info_JSON['all_camera_names']

# Extract all actions from all subjects and find unique values
all_actions_list = [action for actions in info_JSON['subj_to_act'].values() for action in actions]
unique_actions = sorted(list(set(all_actions_list)))

print(f"Number of unique actions: {len(unique_actions)}")
print("Unique actions:")
print(unique_actions)
# Out:
# JSON loaded successfully as a series:
# subj_to_act         {'s03': ['band_pull_apart', 'dumbbell_high_pul...
# test_subj_names                                       [s02, s12, s13]
# train_subj_names             [s03, s04, s05, s07, s08, s09, s10, s11]
# all_camera_names             [50591643, 58860488, 60457274, 65906101]
# dtype: object
# Number of unique actions: 47
# Unique actions:
# ['band_pull_apart', 'barbell_dead_row', 'barbell_row', 'barbell_shrug', 'burpees', 'clean_and_press', 'deadlift', 'diamond_pushup', 'drag_curl', 'dumbbell_biceps_curls', 'dumbbell_curl_trifecta', 'dumbbell_hammer_curls', 'dumbbell_high_pulls', 'dumbbell_overhead_shoulder_press', 'dumbbell_reverse_lunge', 'dumbbell_scaptions', 'man_maker', 'mule_kick', 'neutral_overhead_shoulder_press', 'one_arm_row', 'overhead_extension_thruster', 'overhead_trap_raises', 'pushup', 'side_lateral_raise', 'squat', 'standing_ab_twists', 'w_raise', 'walk_the_box', 'warmup_1', 'warmup_10', 'warmup_11', 'warmup_12', 'warmup_13', 'warmup_14', 'warmup_15', 'warmup_16', 'warmup_17', 'warmup_18', 'warmup_19', 'warmup_2', 'warmup_3', 'warmup_4', 'warmup_5', 'warmup_6', 'warmup_7', 'warmup_8', 'warmup_9']

# %% [markdown]
# # 4. Exercise Availability Table

# %%
# Create a binary matrix: subjects as columns, exercises as rows
subj_to_act = info_JSON['subj_to_act']
subjects = sorted(subj_to_act.keys())

# Initialize data for the table
table_data = {}
for subj in subjects:
    subj_actions = set(subj_to_act[subj])
    # Check if each unique action is performed by this subject
    table_data[subj] = [action in subj_actions for action in unique_actions]

# Create DataFrame
exercise_table = pd.DataFrame(table_data, index=unique_actions)

# Display the table
print("Exercise Availability Table (True if subject has the exercise):")
display(exercise_table)
# Out:
# Exercise Availability Table (True if subject has the exercise):
#                                    s02   s03   s04   s05   s07   s08   s09  \
# band_pull_apart                   True  True  True  True  True  True  True
# barbell_dead_row                  True  True  True  True  True  True  True
# barbell_row                       True  True  True  True  True  True  True
# barbell_shrug                     True  True  True  True  True  True  True
# burpees                           True  True  True  True  True  True  True
# clean_and_press                   True  True  True  True  True  True  True
# deadlift                          True  True  True  True  True  True  True
# diamond_pushup                    True  True  True  True  True  True  True
# drag_curl                         True  True  True  True  True  True  True
# dumbbell_biceps_curls             True  True  True  True  True  True  True
# dumbbell_curl_trifecta            True  True  True  True  True  True  True
# dumbbell_hammer_curls             True  True  True  True  True  True  True
# dumbbell_high_pulls               True  True  True  True  True  True  True
# dumbbell_overhead_shoulder_press  True  True  True  True  True  True  True
# dumbbell_reverse_lunge            True  True  True  True  True  True  True
# dumbbell_scaptions                True  True  True  True  True  True  True
# man_maker                         True  True  True  True  True  True  True
# mule_kick                         True  True  True  True  True  True  True
# neutral_overhead_shoulder_press   True  True  True  True  True  True  True
# one_arm_row                       True  True  True  True  True  True  True
# overhead_extension_thruster       True  True  True  True  True  True  True
# overhead_trap_raises              True  True  True  True  True  True  True
# pushup                            True  True  True  True  True  True  True
# side_lateral_raise                True  True  True  True  True  True  True
# squat                             True  True  True  True  True  True  True
# standing_ab_twists                True  True  True  True  True  True  True
# w_raise                           True  True  True  True  True  True  True
# walk_the_box                      True  True  True  True  True  True  True
# warmup_1                          True  True  True  True  True  True  True
# warmup_10                         True  True  True  True  True  True  True
# warmup_11                         True  True  True  True  True  True  True
# warmup_12                         True  True  True  True  True  True  True
# warmup_13                         True  True  True  True  True  True  True
# warmup_14                         True  True  True  True  True  True  True
# warmup_15                         True  True  True  True  True  True  True
# warmup_16                         True  True  True  True  True  True  True
# warmup_17                         True  True  True  True  True  True  True
# warmup_18                         True  True  True  True  True  True  True
# warmup_19                         True  True  True  True  True  True  True
# warmup_2                          True  True  True  True  True  True  True
# warmup_3                          True  True  True  True  True  True  True
# warmup_4                          True  True  True  True  True  True  True
# warmup_5                          True  True  True  True  True  True  True
# warmup_6                          True  True  True  True  True  True  True
# warmup_7                          True  True  True  True  True  True  True
# warmup_8                          True  True  True  True  True  True  True
# warmup_9                          True  True  True  True  True  True  True
#
#                                    s10   s11   s12   s13
# band_pull_apart                   True  True  True  True
# barbell_dead_row                  True  True  True  True
# barbell_row                       True  True  True  True
# barbell_shrug                     True  True  True  True
# burpees                           True  True  True  True
# clean_and_press                   True  True  True  True
# deadlift                          True  True  True  True
# diamond_pushup                    True  True  True  True
# drag_curl                         True  True  True  True
# dumbbell_biceps_curls             True  True  True  True
# dumbbell_curl_trifecta            True  True  True  True
# dumbbell_hammer_curls             True  True  True  True
# dumbbell_high_pulls               True  True  True  True
# dumbbell_overhead_shoulder_press  True  True  True  True
# dumbbell_reverse_lunge            True  True  True  True
# dumbbell_scaptions                True  True  True  True
# man_maker                         True  True  True  True
# mule_kick                         True  True  True  True
# neutral_overhead_shoulder_press   True  True  True  True
# one_arm_row                       True  True  True  True
# overhead_extension_thruster       True  True  True  True
# overhead_trap_raises              True  True  True  True
# pushup                            True  True  True  True
# side_lateral_raise                True  True  True  True
# squat                             True  True  True  True
# standing_ab_twists                True  True  True  True
# w_raise                           True  True  True  True
# walk_the_box                      True  True  True  True
# warmup_1                          True  True  True  True
# warmup_10                         True  True  True  True
# warmup_11                         True  True  True  True
# warmup_12                         True  True  True  True
# warmup_13                         True  True  True  True
# warmup_14                         True  True  True  True
# warmup_15                         True  True  True  True
# warmup_16                         True  True  True  True
# warmup_17                         True  True  True  True
# warmup_18                         True  True  True  True
# warmup_19                         True  True  True  True
# warmup_2                          True  True  True  True
# warmup_3                          True  True  True  True
# warmup_4                          True  True  True  True
# warmup_5                          True  True  True  True
# warmup_6                          True  True  True  True
# warmup_7                          True  True  True  True
# warmup_8                          True  True  True  True
# warmup_9                          True  True  True  True

# %% [markdown]
# # 5. Mediapipe 3D Pose Evaluation
# ## 5.1 Configuration & Indices

# %%
# MediaPipe Pose setup
mp_pose = mp.solutions.pose

# Joint subset ordered by H36M joint index.
# Joint:        [ L_Hip, L_Knee, L_Ankle,  R_Hip, R_Knee, R_Ankle,  L_Shoulder, L_Elbow, L_Wrist, R_Shoulder, R_Elbow, R_Wrist]
fit3d_indices = [    1,      2,      3,     4,      5,       6,            11,     12,     13,          14,      15,       16]
mp_indices    = [   23,     25,      27,    24,     26,      28,           11,      13,      15,         12,      14,      16]

# %% [markdown]
# ## 5.2 Utilities (Procrustes Alignment & Metric)

# %%
def procrustes_alignment_batched(pred, target):
    """
    Batched Procrustes alignment.
    pred, target: (num_frames, num_joints, 3)
    """
    mu_p = np.mean(pred, axis=1, keepdims=True)
    mu_t = np.mean(target, axis=1, keepdims=True)
    
    p_0 = pred - mu_p
    t_0 = target - mu_t
    
    norm_p = np.linalg.norm(p_0, axis=(1, 2), keepdims=True)
    norm_t = np.linalg.norm(t_0, axis=(1, 2), keepdims=True)
    norm_t = np.where(norm_t == 0, 1e-8, norm_t)
    norm_p = np.where(norm_p == 0, 1e-8, norm_p)
    
    p_0 = p_0 / norm_p
    t_0 = t_0 / norm_t
    
    # Kabsch algorithm (batched)
    H = np.matmul(p_0.transpose(0, 2, 1), t_0)
    U, S, Vt = np.linalg.svd(H)
    
    detR = np.linalg.det(np.matmul(Vt.transpose(0, 2, 1), U.transpose(0, 2, 1)))
    V_adj = Vt.transpose(0, 2, 1).copy()
    V_adj[detR < 0, :, 2] *= -1
    R = np.matmul(V_adj, U.transpose(0, 2, 1))
    
    aligned = np.matmul(p_0, R.transpose(0, 2, 1)) * norm_t + mu_t
    return aligned

def calculate_pa_mpjpe(pred_3d, gt_3d, mp_idx, gt_idx):
    """
    PA-MPJPE (Procrustes-Aligned MPJPE) — the primary evaluation metric.
    Removes the effect of global rotation, translation, and scale.
    pred_3d, gt_3d: full joint arrays in mm
    """
    num_frames = min(len(pred_3d), len(gt_3d))
    if num_frames == 0: return 0.0
    
    p_subset = np.array(pred_3d[:num_frames])[:, mp_idx]
    g_subset = np.array(gt_3d[:num_frames])[:, gt_idx]
    
    p_aligned = procrustes_alignment_batched(p_subset, g_subset)
    dist = np.linalg.norm(p_aligned - g_subset, axis=-1)
    return np.mean(dist)

# %% [markdown]
# # 6. Define MediaPipe 3D Processing Function

# %%
def predict_mediapipe_3d(video_path, complexity):
    pred_3d_list = []
    cap = cv2.VideoCapture(video_path)
    import time
    total_inference_time = 0.0
    total_frames = 0
    
    mp_pose = mp.solutions.pose
    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5, model_complexity=complexity, static_image_mode=False) as pose:
        last_pose = np.zeros((33, 3))
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret: break
                
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            
            # 1. Start the high-precision timer
            start_time = time.perf_counter()

            # 2. Run ONLY the model inference
            results = pose.process(image)

            # 3. Stop the timer
            end_time = time.perf_counter()

            # 4. Calculate exactly how long this one frame took
            frame_time = end_time - start_time
            total_inference_time += frame_time
            total_frames += 1
            
            if results.pose_world_landmarks:
                # 3D relative world landmarks
                world_lms = np.array([[lm.x, lm.y, lm.z] for lm in results.pose_world_landmarks.landmark])
                pred_3d_list.append(world_lms)
                last_pose = world_lms
            else:
                pred_3d_list.append(last_pose)
    
    cap.release()
    average_fps = total_frames / total_inference_time if total_inference_time > 0 else 0.0
    if len(pred_3d_list) == 0:
        return None, average_fps
    return np.array(pred_3d_list), average_fps

# %% [markdown]
# # 7. Validation Evaluation Pipeline

# %% [markdown]
# ## 7.1 Generate Validation Tasks

# %%
def get_validation_tasks(dataset_base, subj_names, all_camera_names):
    tasks = []
    base_path = Path(dataset_base)
    for subj in subj_names:
        ref_dir = base_path / "train" / subj / "joints3d_25"
        if not ref_dir.exists(): continue
        for ref_file in ref_dir.glob("*.json"):
            action = ref_file.stem
            gt_3d = None
            for cam_id in np.random.choice(all_camera_names, 1, replace=False):
                v_path = base_path / "train" / subj / "videos" / str(cam_id) / f"{action}.mp4"
                if v_path.exists():
                    if gt_3d is None:
                        with open(ref_file, 'r') as f:
                            gt_data = json.load(f)
                            gt_3d = np.array(gt_data.get('joints3d_25', list(gt_data.values())[0])) if isinstance(gt_data, dict) else np.array(gt_data)
                    tasks.append({'subj': subj, 'action': action, 'cam_id': cam_id, 'video_path': str(v_path), 'gt_3d': gt_3d})
    return tasks

# %% [markdown]
# ## 7.2 Validation Execution Pipeline

# %%
def evaluate_validation_set(tasks, predict_func, complexity, mp_indices, fit3d_indices):
    print(f"Starting parallel validation evaluation of {len(tasks)} videos...", flush=True)
    all_pa_mpjpe = []
    all_fps = []
    action_pa_mpjpe = {}
    
    def process_task(t):
        result = predict_func(t['video_path'], complexity)
        if result is None or result[0] is None: return None
        pred_3d_raw, average_fps = result
        
        gt_3d_mm   = t['gt_3d'] * 1000
        pred_3d_mm = pred_3d_raw * 1000.0
        try:
            pa = calculate_pa_mpjpe(pred_3d_mm, gt_3d_mm, mp_indices, fit3d_indices)
            return (t['subj'], t['action'], t['cam_id'], pa, average_fps)
        except Exception as e:
            return ('ERROR', t['subj'], t['action'], t.get('cam_id', 'TestCam'), e, 0.0)
        
    with concurrent.futures.ThreadPoolExecutor(max_workers=3) as executor:
        futures = [executor.submit(process_task, t) for t in tasks]
        for future in tqdm(concurrent.futures.as_completed(futures), total=len(tasks), desc="Evaluating Pose"):
            res = future.result()
            if isinstance(res, tuple) and res[0] == 'ERROR':
                print(f"\nERROR processing {res[1]} | {res[2]} (Cam {res[3]}): {res[4]}")
            else:
                subj, action, cam_id, pa, average_fps = res
                all_pa_mpjpe.append(pa)
                action_pa_mpjpe.setdefault(action, []).append(pa)
                if average_fps > 0:
                    all_fps.append(average_fps)
                
    if all_pa_mpjpe:
        print("\n\n--- PA-MPJPE per Exercise ---")
        for act in sorted(action_pa_mpjpe.keys()):
            print(f"{act:15s}: PA-MPJPE = {np.mean(action_pa_mpjpe[act]):6.2f} mm")
        print(f"\nOverall Mean PA-MPJPE: {np.mean(all_pa_mpjpe):.2f} mm")
        if all_fps:
            print(f"Overall Mean FPS: {np.mean(all_fps):.2f} FPS")
    return all_pa_mpjpe

# %% [markdown]
# # 8. Define MediaPipe 2D Processing Function

# %%
def predict_mediapipe_2d(video_path, complexity):
    pred_2d_list = []
    cap = cv2.VideoCapture(video_path)
    import time
    total_inference_time = 0.0
    total_frames = 0
    
    mp_pose = mp.solutions.pose
    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5, model_complexity=complexity, static_image_mode=False) as pose:
        last_pose = np.zeros((33, 3))
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret: break
                
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            
            # 1. Start the high-precision timer
            start_time = time.perf_counter()

            # 2. Run ONLY the model inference
            results = pose.process(image)

            # 3. Stop the timer
            end_time = time.perf_counter()

            # 4. Calculate exactly how long this one frame took
            frame_time = end_time - start_time
            total_inference_time += frame_time
            total_frames += 1
            height, width, _ = frame.shape
            
            if results.pose_landmarks:
                # 2D relative landmarks scaled to image dimensions
                lms = np.array([[lm.x * width, lm.y * height, lm.z * width] for lm in results.pose_landmarks.landmark])
                pred_2d_list.append(lms)
                last_pose = lms
            else:
                pred_2d_list.append(last_pose)
    
    cap.release()
    average_fps = total_frames / total_inference_time if total_inference_time > 0 else 0.0
    if len(pred_2d_list) == 0:
        return None, average_fps
    return np.array(pred_2d_list), average_fps

# %% [markdown]
# # 9. Execute Experiments (PA-MPJPE)

# %%
val_tasks = get_validation_tasks(dataset_Folder, val_subj_names, all_camera_names)

# %% [markdown]
# ## Phase 1: 2D vs 3D (complexity = 1)

# %% [markdown]
# ### Experiment 1: Medipipe 2D – complexity = 1

# %%
print("========== Experiment 1: Medipipe 2D – complexity = 1 ==========")
_ = evaluate_validation_set(val_tasks, predict_mediapipe_2d, complexity=1, mp_indices=mp_indices, fit3d_indices=fit3d_indices)
# Out:
# ========== Experiment 1: Medipipe 2D – complexity = 1 ==========
# Starting parallel validation evaluation of 94 videos...
# Evaluating Pose: 100%|██████████| 94/94 [36:02<00:00, 23.01s/it]
# --- PA-MPJPE per Exercise ---
# band_pull_apart: PA-MPJPE = 175.59 mm
# barbell_dead_row: PA-MPJPE = 205.14 mm
# barbell_row    : PA-MPJPE = 188.59 mm
# barbell_shrug  : PA-MPJPE = 154.17 mm
# burpees        : PA-MPJPE = 197.68 mm
# clean_and_press: PA-MPJPE = 207.34 mm
# deadlift       : PA-MPJPE = 185.16 mm
# diamond_pushup : PA-MPJPE = 181.91 mm
# drag_curl      : PA-MPJPE = 196.63 mm
# dumbbell_biceps_curls: PA-MPJPE = 186.61 mm
# dumbbell_curl_trifecta: PA-MPJPE = 174.66 mm
# dumbbell_hammer_curls: PA-MPJPE = 192.32 mm
# dumbbell_high_pulls: PA-MPJPE = 202.17 mm
# dumbbell_overhead_shoulder_press: PA-MPJPE = 171.82 mm
# dumbbell_reverse_lunge: PA-MPJPE = 186.43 mm
# dumbbell_scaptions: PA-MPJPE = 170.60 mm
# man_maker      : PA-MPJPE = 208.27 mm
# mule_kick      : PA-MPJPE = 240.40 mm
# neutral_overhead_shoulder_press: PA-MPJPE = 179.92 mm
# one_arm_row    : PA-MPJPE = 217.46 mm
# overhead_extension_thruster: PA-MPJPE = 189.63 mm
# overhead_trap_raises: PA-MPJPE = 204.00 mm
# pushup         : PA-MPJPE = 183.71 mm
# side_lateral_raise: PA-MPJPE = 161.84 mm
# squat          : PA-MPJPE = 249.64 mm
# standing_ab_twists: PA-MPJPE = 226.53 mm
# w_raise        : PA-MPJPE = 179.47 mm
# walk_the_box   : PA-MPJPE = 224.90 mm
# warmup_1       : PA-MPJPE = 200.60 mm
# warmup_10      : PA-MPJPE = 211.20 mm
# warmup_11      : PA-MPJPE = 197.60 mm
# warmup_12      : PA-MPJPE = 211.11 mm
# warmup_13      : PA-MPJPE = 186.05 mm
# warmup_14      : PA-MPJPE = 152.11 mm
# warmup_15      : PA-MPJPE = 164.59 mm
# warmup_16      : PA-MPJPE = 217.18 mm
# warmup_17      : PA-MPJPE = 159.99 mm
# warmup_18      : PA-MPJPE = 184.70 mm
# warmup_19      : PA-MPJPE = 177.30 mm
# warmup_2       : PA-MPJPE = 188.30 mm
# warmup_3       : PA-MPJPE = 202.78 mm
# warmup_4       : PA-MPJPE = 206.98 mm
# warmup_5       : PA-MPJPE = 157.59 mm
# warmup_6       : PA-MPJPE = 144.14 mm
# warmup_7       : PA-MPJPE = 156.27 mm
# warmup_8       : PA-MPJPE = 135.63 mm
# warmup_9       : PA-MPJPE = 165.02 mm
#
# Overall Mean PA-MPJPE: 188.55 mm
# Overall Mean FPS: 23.58 FPS

# %% [markdown]
# ### Experiment 2: Medipipe 3D – complexity = 1

# %%
print("========== Experiment 2: Medipipe 3D – complexity = 1 ==========")
_ = evaluate_validation_set(val_tasks, predict_mediapipe_3d, complexity=1, mp_indices=mp_indices, fit3d_indices=fit3d_indices)
# Out:
# ========== Experiment 2: Medipipe 3D – complexity = 1 ==========
# Starting parallel validation evaluation of 94 videos...
# Evaluating Pose: 100%|██████████| 94/94 [34:37<00:00, 22.10s/it]
# --- PA-MPJPE per Exercise ---
# band_pull_apart: PA-MPJPE =  68.07 mm
# barbell_dead_row: PA-MPJPE =  84.43 mm
# barbell_row    : PA-MPJPE =  99.76 mm
# barbell_shrug  : PA-MPJPE =  69.33 mm
# burpees        : PA-MPJPE = 111.40 mm
# clean_and_press: PA-MPJPE =  78.07 mm
# deadlift       : PA-MPJPE =  71.64 mm
# diamond_pushup : PA-MPJPE =  95.47 mm
# drag_curl      : PA-MPJPE =  90.61 mm
# dumbbell_biceps_curls: PA-MPJPE =  61.56 mm
# dumbbell_curl_trifecta: PA-MPJPE =  67.28 mm
# dumbbell_hammer_curls: PA-MPJPE =  65.04 mm
# dumbbell_high_pulls: PA-MPJPE =  69.58 mm
# dumbbell_overhead_shoulder_press: PA-MPJPE =  70.40 mm
# dumbbell_reverse_lunge: PA-MPJPE =  83.92 mm
# dumbbell_scaptions: PA-MPJPE =  66.18 mm
# man_maker      : PA-MPJPE = 122.80 mm
# mule_kick      : PA-MPJPE = 134.11 mm
# neutral_overhead_shoulder_press: PA-MPJPE =  73.53 mm
# one_arm_row    : PA-MPJPE =  90.83 mm
# overhead_extension_thruster: PA-MPJPE =  78.06 mm
# overhead_trap_raises: PA-MPJPE =  72.98 mm
# pushup         : PA-MPJPE = 117.35 mm
# side_lateral_raise: PA-MPJPE =  75.15 mm
# squat          : PA-MPJPE = 103.47 mm
# standing_ab_twists: PA-MPJPE = 107.39 mm
# w_raise        : PA-MPJPE =  73.41 mm
# walk_the_box   : PA-MPJPE =  89.77 mm
# warmup_1       : PA-MPJPE = 136.50 mm
# warmup_10      : PA-MPJPE =  77.19 mm
# warmup_11      : PA-MPJPE =  69.83 mm
# warmup_12      : PA-MPJPE = 100.52 mm
# warmup_13      : PA-MPJPE = 113.69 mm
# warmup_14      : PA-MPJPE =  70.60 mm
# warmup_15      : PA-MPJPE =  69.04 mm
# warmup_16      : PA-MPJPE = 107.06 mm
# warmup_17      : PA-MPJPE =  78.56 mm
# warmup_18      : PA-MPJPE =  73.65 mm
# warmup_19      : PA-MPJPE =  79.14 mm
# warmup_2       : PA-MPJPE =  88.44 mm
# warmup_3       : PA-MPJPE =  84.16 mm
# warmup_4       : PA-MPJPE =  85.72 mm
# warmup_5       : PA-MPJPE = 111.72 mm
# warmup_6       : PA-MPJPE =  59.19 mm
# warmup_7       : PA-MPJPE =  64.79 mm
# warmup_8       : PA-MPJPE =  55.19 mm
# warmup_9       : PA-MPJPE =  76.13 mm
#
# Overall Mean PA-MPJPE: 84.95 mm
# Overall Mean FPS: 24.31 FPS

# %% [markdown]
# ## Phase 2: 3D Model with different complexities {0, 1, 2}
# Because 3D demonstrated better performance, we compare it across varying complexities.

# %% [markdown]
# ### Experiment 3: Medipipe 3D – complexity = 0

# %%
print("========== Experiment 3: Medipipe 3D – complexity = 0 ==========")
_ = evaluate_validation_set(val_tasks, predict_mediapipe_3d, complexity=0, mp_indices=mp_indices, fit3d_indices=fit3d_indices)
# Out:
# ========== Experiment 3: Medipipe 3D – complexity = 0 ==========
# Starting parallel validation evaluation of 94 videos...
# Evaluating Pose: 100%|██████████| 94/94 [28:45<00:00, 18.36s/it]
# --- PA-MPJPE per Exercise ---
# band_pull_apart: PA-MPJPE =  71.38 mm
# barbell_dead_row: PA-MPJPE =  90.62 mm
# barbell_row    : PA-MPJPE =  96.42 mm
# barbell_shrug  : PA-MPJPE =  65.23 mm
# burpees        : PA-MPJPE = 108.27 mm
# clean_and_press: PA-MPJPE =  80.04 mm
# deadlift       : PA-MPJPE =  78.10 mm
# diamond_pushup : PA-MPJPE = 104.66 mm
# drag_curl      : PA-MPJPE =  93.58 mm
# dumbbell_biceps_curls: PA-MPJPE =  63.31 mm
# dumbbell_curl_trifecta: PA-MPJPE =  67.92 mm
# dumbbell_hammer_curls: PA-MPJPE =  61.43 mm
# dumbbell_high_pulls: PA-MPJPE =  72.41 mm
# dumbbell_overhead_shoulder_press: PA-MPJPE =  75.77 mm
# dumbbell_reverse_lunge: PA-MPJPE =  90.24 mm
# dumbbell_scaptions: PA-MPJPE =  70.45 mm
# man_maker      : PA-MPJPE = 126.62 mm
# mule_kick      : PA-MPJPE = 130.25 mm
# neutral_overhead_shoulder_press: PA-MPJPE =  71.44 mm
# one_arm_row    : PA-MPJPE =  91.61 mm
# overhead_extension_thruster: PA-MPJPE =  80.91 mm
# overhead_trap_raises: PA-MPJPE =  70.17 mm
# pushup         : PA-MPJPE = 128.02 mm
# side_lateral_raise: PA-MPJPE =  68.56 mm
# squat          : PA-MPJPE = 105.49 mm
# standing_ab_twists: PA-MPJPE = 141.51 mm
# w_raise        : PA-MPJPE =  75.01 mm
# walk_the_box   : PA-MPJPE = 100.39 mm
# warmup_1       : PA-MPJPE = 141.78 mm
# warmup_10      : PA-MPJPE =  83.19 mm
# warmup_11      : PA-MPJPE =  66.36 mm
# warmup_12      : PA-MPJPE = 115.16 mm
# warmup_13      : PA-MPJPE = 123.73 mm
# warmup_14      : PA-MPJPE =  66.89 mm
# warmup_15      : PA-MPJPE =  68.44 mm
# warmup_16      : PA-MPJPE = 117.04 mm
# warmup_17      : PA-MPJPE =  83.49 mm
# warmup_18      : PA-MPJPE =  80.99 mm
# warmup_19      : PA-MPJPE =  83.17 mm
# warmup_2       : PA-MPJPE = 106.23 mm
# warmup_3       : PA-MPJPE =  94.54 mm
# warmup_4       : PA-MPJPE = 119.08 mm
# warmup_5       : PA-MPJPE = 128.01 mm
# warmup_6       : PA-MPJPE =  66.85 mm
# warmup_7       : PA-MPJPE =  73.66 mm
# warmup_8       : PA-MPJPE =  54.26 mm
# warmup_9       : PA-MPJPE =  79.24 mm
#
# Overall Mean PA-MPJPE: 90.04 mm
# Overall Mean FPS: 30.77 FPS

# %% [markdown]
# ### Experiment 4: Medipipe 3D – complexity = 1

# %%
print("========== Experiment 4: Medipipe 3D – complexity = 1 ==========")
_ = evaluate_validation_set(val_tasks, predict_mediapipe_3d, complexity=1, mp_indices=mp_indices, fit3d_indices=fit3d_indices)
# Out:
# ========== Experiment 4: Medipipe 3D – complexity = 1 ==========
# Starting parallel validation evaluation of 94 videos...
# Evaluating Pose: 100%|██████████| 94/94 [38:41<00:00, 24.69s/it]
# --- PA-MPJPE per Exercise ---
# band_pull_apart: PA-MPJPE =  68.07 mm
# barbell_dead_row: PA-MPJPE =  84.43 mm
# barbell_row    : PA-MPJPE =  99.76 mm
# barbell_shrug  : PA-MPJPE =  69.33 mm
# burpees        : PA-MPJPE = 111.40 mm
# clean_and_press: PA-MPJPE =  78.07 mm
# deadlift       : PA-MPJPE =  71.64 mm
# diamond_pushup : PA-MPJPE =  95.47 mm
# drag_curl      : PA-MPJPE =  90.61 mm
# dumbbell_biceps_curls: PA-MPJPE =  61.56 mm
# dumbbell_curl_trifecta: PA-MPJPE =  67.28 mm
# dumbbell_hammer_curls: PA-MPJPE =  65.04 mm
# dumbbell_high_pulls: PA-MPJPE =  69.58 mm
# dumbbell_overhead_shoulder_press: PA-MPJPE =  70.40 mm
# dumbbell_reverse_lunge: PA-MPJPE =  83.92 mm
# dumbbell_scaptions: PA-MPJPE =  66.18 mm
# man_maker      : PA-MPJPE = 122.80 mm
# mule_kick      : PA-MPJPE = 134.11 mm
# neutral_overhead_shoulder_press: PA-MPJPE =  73.53 mm
# one_arm_row    : PA-MPJPE =  90.83 mm
# overhead_extension_thruster: PA-MPJPE =  78.06 mm
# overhead_trap_raises: PA-MPJPE =  72.98 mm
# pushup         : PA-MPJPE = 117.35 mm
# side_lateral_raise: PA-MPJPE =  75.15 mm
# squat          : PA-MPJPE = 103.47 mm
# standing_ab_twists: PA-MPJPE = 107.39 mm
# w_raise        : PA-MPJPE =  73.41 mm
# walk_the_box   : PA-MPJPE =  89.77 mm
# warmup_1       : PA-MPJPE = 136.50 mm
# warmup_10      : PA-MPJPE =  77.19 mm
# warmup_11      : PA-MPJPE =  69.83 mm
# warmup_12      : PA-MPJPE = 100.52 mm
# warmup_13      : PA-MPJPE = 113.69 mm
# warmup_14      : PA-MPJPE =  70.60 mm
# warmup_15      : PA-MPJPE =  69.04 mm
# warmup_16      : PA-MPJPE = 107.06 mm
# warmup_17      : PA-MPJPE =  78.56 mm
# warmup_18      : PA-MPJPE =  73.65 mm
# warmup_19      : PA-MPJPE =  79.14 mm
# warmup_2       : PA-MPJPE =  88.44 mm
# warmup_3       : PA-MPJPE =  84.16 mm
# warmup_4       : PA-MPJPE =  85.72 mm
# warmup_5       : PA-MPJPE = 111.72 mm
# warmup_6       : PA-MPJPE =  59.19 mm
# warmup_7       : PA-MPJPE =  64.79 mm
# warmup_8       : PA-MPJPE =  55.19 mm
# warmup_9       : PA-MPJPE =  76.13 mm
#
# Overall Mean PA-MPJPE: 84.95 mm
# Overall Mean FPS: 21.53 FPS

# %% [markdown]
# ### Experiment 5: Medipipe 3D – complexity = 2

# %%
print("========== Experiment 5: Medipipe 3D – complexity = 2 ==========")
_ = evaluate_validation_set(val_tasks, predict_mediapipe_3d, complexity=2, mp_indices=mp_indices, fit3d_indices=fit3d_indices)
# Out:
# ========== Experiment 5: Medipipe 3D – complexity = 2 ==========
# Starting parallel validation evaluation of 94 videos...
# Evaluating Pose: 100%|██████████| 94/94 [1:53:19<00:00, 72.34s/it]
# --- PA-MPJPE per Exercise ---
# band_pull_apart: PA-MPJPE =  78.60 mm
# barbell_dead_row: PA-MPJPE =  84.34 mm
# barbell_row    : PA-MPJPE =  99.21 mm
# barbell_shrug  : PA-MPJPE =  81.20 mm
# burpees        : PA-MPJPE = 115.67 mm
# clean_and_press: PA-MPJPE =  87.78 mm
# deadlift       : PA-MPJPE =  78.54 mm
# diamond_pushup : PA-MPJPE = 129.44 mm
# drag_curl      : PA-MPJPE =  95.69 mm
# dumbbell_biceps_curls: PA-MPJPE =  69.76 mm
# dumbbell_curl_trifecta: PA-MPJPE =  74.86 mm
# dumbbell_hammer_curls: PA-MPJPE =  68.60 mm
# dumbbell_high_pulls: PA-MPJPE =  78.35 mm
# dumbbell_overhead_shoulder_press: PA-MPJPE =  78.98 mm
# dumbbell_reverse_lunge: PA-MPJPE =  88.82 mm
# dumbbell_scaptions: PA-MPJPE =  75.00 mm
# man_maker      : PA-MPJPE = 150.73 mm
# mule_kick      : PA-MPJPE = 115.66 mm
# neutral_overhead_shoulder_press: PA-MPJPE =  80.34 mm
# one_arm_row    : PA-MPJPE = 105.75 mm
# overhead_extension_thruster: PA-MPJPE =  97.26 mm
# overhead_trap_raises: PA-MPJPE =  75.92 mm
# pushup         : PA-MPJPE = 157.22 mm
# side_lateral_raise: PA-MPJPE =  78.43 mm
# squat          : PA-MPJPE = 104.45 mm
# standing_ab_twists: PA-MPJPE = 119.66 mm
# w_raise        : PA-MPJPE =  84.40 mm
# walk_the_box   : PA-MPJPE = 106.20 mm
# warmup_1       : PA-MPJPE = 191.73 mm
# warmup_10      : PA-MPJPE =  80.94 mm
# warmup_11      : PA-MPJPE =  78.54 mm
# warmup_12      : PA-MPJPE =  99.56 mm
# warmup_13      : PA-MPJPE = 133.38 mm
# warmup_14      : PA-MPJPE =  73.96 mm
# warmup_15      : PA-MPJPE =  70.18 mm
# warmup_16      : PA-MPJPE = 110.62 mm
# warmup_17      : PA-MPJPE =  84.43 mm
# warmup_18      : PA-MPJPE =  80.03 mm
# warmup_19      : PA-MPJPE =  88.55 mm
# warmup_2       : PA-MPJPE =  95.31 mm
# warmup_3       : PA-MPJPE =  83.99 mm
# warmup_4       : PA-MPJPE = 100.78 mm
# warmup_5       : PA-MPJPE = 117.96 mm
# warmup_6       : PA-MPJPE =  69.64 mm
# warmup_7       : PA-MPJPE =  74.60 mm
# warmup_8       : PA-MPJPE =  70.27 mm
# warmup_9       : PA-MPJPE =  83.10 mm
#
# Overall Mean PA-MPJPE: 94.65 mm
# Overall Mean FPS: 6.50 FPS
